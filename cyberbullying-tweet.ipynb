# %% [markdown]
# # Context
# With rise of social media coupled with the Covid-19 pandemic, cyberbullying has reached all time highs. We can combat this by creating models to automatically flag potentially harmful tweets as well as break down the patterns of hatred.
#
# # About Dataset
# As social media usage becomes increasingly prevalent in every age group, a vast majority of citizens rely on this essential medium for day-to-day communication. Social media’s ubiquity means that cyberbullying can effectively impact anyone at any time or anywhere, and the relative anonymity
# of the internet makes such personal attacks more difficult to stop than traditional bullying.
#
# On April 15th, 2020, UNICEF issued a warning in response to the increased risk of cyberbullying during the COVID-19 pandemic due to widespread school closures, increased screen time, and decreased face-to-face social interaction. The statistics of cyberbullying are outright alarming: 36.5% of middle and high school students have felt cyberbullied and 87% have observed cyberbullying, with effects ranging from decreased academic performance to depression to suicidal thoughts.
#
# # Variables
# In light of all of this, this dataset contains more than 47000 tweets labelled according to the class of cyberbullying:
#
# __Age
# Ethnicity
# Gender
# Religion
# Other type of cyberbullying
# Not cyberbullying__
#
# # Objective
# The objective of this project is to create a model that can automatically flag potentially harmful tweets as well as break down the patterns of hatred

# %% [markdown]
# # Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import emoji
import string
import nltk
from PIL import Image
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
import pickle
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/winar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Getting data

# %%
data = pd.read_csv('cyberbullying_tweets.csv')

# %% [markdown]
# # Initial Review

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
data.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# # Checking Missing Values

# %%
data.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %% [markdown]
# ## No Missing Values found!

# %%
data['cyberbullying_type'].value_counts()
# Out:
# cyberbullying_type
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: count, dtype: int64

# %% [markdown]
# ## Renaming columns for better understanding

# %%
data = data.rename(columns={'tweet_text': 'text', 'cyberbullying_type': 'sentiment'})

# %%
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# ### Adding Encoded column for sentiments

# %%
data["sentiment_encoded"] = data['sentiment'].replace({"religion": 1, "age": 2, "ethnicity": 3, "gender": 4, "other_cyberbullying": 5,"not_cyberbullying": 6})

# %%
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying  \
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded
# 0                  6
# 1                  6
# 2                  6
# 3                  6
# 4                  6

# %%
stopwords.words('english')
STOPWORDS.update(['rt', 'mkr', 'didn', 'bc', 'n', 'm', 'im', 'll', 'y', 've', 'u', 'ur', 'don', 't','U','dont', 's','will','would','am','say','one','im',':p',':)',':D'])
stop_words = set(STOPWORDS)

# %% [markdown]
# # Preprocessing of Text

# %% [markdown]
# ## Function to Remove Emojis

# %%
def strip_emoji(text):
    return emoji.replace_emoji(text,replace="")

# %% [markdown]
# ## Fucntion to Convert text to lowercase, remove (/r, /n  characters), URLs, non-utf characters, Numbers, punctuations,stopwords

# %%
def strip_all_entities(text): 
    text = text.replace('\r', '').replace('\n', ' ').lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub(r'[^\x00-\x7f]',r'', text)
    text = re.sub(r'(.)1+', r'1', text)
    text = re.sub('[0-9]+', '', text)
    stopchars= string.punctuation
    table = str.maketrans('', '', stopchars)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    return text

# %% [markdown]
# ## Function to remove contractions

# %%
def decontract(text):
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    return text

# %% [markdown]
# ## Function to Clean Hashtags

# %%
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', tweet))
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet))
    return new_tweet2

# %% [markdown]
# ## Function to Filter Special Characters such as $, &

# %%
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if ('$' in word) | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

# %% [markdown]
# ## Function to remove mutiple sequence spaces

# %%
def remove_mult_spaces(text):
    return re.sub("\s\s+" , " ", text)

# %% [markdown]
# ## Function to apply stemming to words

# %%
def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

# %% [markdown]
# ## Function to apply lemmatization to words

# %%
def lemmatize(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])

# %% [markdown]
# ## Function to Preprocess the text by applying all above functions

# %%
def preprocess(text):
    text = strip_emoji(text)
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
    text = lemmatize(text)
    return text

# %%
data['cleaned_text'] = data['text'].apply(preprocess)
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying  \
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text
# 0                  6                     word katandandr food crapilici
# 1                  6  aussietv white theblock imacelebrityau today s...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6      isi account pretend kurdish account islam lie

# %% [markdown]
# ## Cleaned text added

# %% [markdown]
# ## Dealing with Duplicates

# %%
data["cleaned_text"].duplicated().sum()
# Out:
# 3318

# %%
data.drop_duplicates("cleaned_text", inplace=True)

# %% [markdown]
# # Duplicates removed

# %% [markdown]
# # Tokenization

# %%
data['tweet_list'] = data['cleaned_text'].apply(word_tokenize)
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying  \
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text
# 0                  6                     word katandandr food crapilici  \
# 1                  6  aussietv white theblock imacelebrityau today s...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6      isi account pretend kurdish account islam lie
#
#                                           tweet_list
# 0                [word, katandandr, food, crapilici]
# 1  [aussietv, white, theblock, imacelebrityau, to...
# 2               [classi, whore, red, velvet, cupcak]
# 3  [meh, p, thank, head, concern, anoth, angri, d...
# 4  [isi, account, pretend, kurdish, account, isla...

# %% [markdown]
# # Checking length of various tweet texts

# %%
text_len = []
for text in data.tweet_list:
    tweet_len = len(text)
    text_len.append(tweet_len)
data['text_len'] = text_len

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x='text_len', data=data, palette='mako')
plt.title('Count of words in tweets', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %% [markdown]
# # Removing text without words

# %%
data = data[data['text_len']!=0]

# %%
data.shape
# Out:
# (44373, 6)

# %% [markdown]
# # Data Result after Preprocessing

# %%
 data['sentiment'].value_counts()
# Out:
# sentiment
# religion               7948
# age                    7867
# ethnicity              7725
# not_cyberbullying      7577
# gender                 7543
# other_cyberbullying    5713
# Name: count, dtype: int64

# %% [markdown]
# # Function to create WordCloud

# %%
from os import path
import os
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
twitter_mask = np.array(Image.open('twitter_mask.png'))
def plot_wordcloud(cyberbullying_type):
    string = ""
    for i in data[data.sentiment == cyberbullying_type].cleaned_text.values:
        string = string + " " + i.strip()

   
    wordcloud = WordCloud(background_color ='white',max_words=2000, max_font_size=256, 
    mask=twitter_mask,
               random_state=42, min_font_size = 10).generate(string)
 
    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(cyberbullying_type)
    plt.show()
    del string

# %% [markdown]
# # Splitting data based on sentiment for Data Exploration

# %%
not_cyberbullying_type = data[data['sentiment']=='not_cyberbullying']
gender_type = data[data['sentiment']=='gender']
religion_type = data[data['sentiment']=='religion']
other_cyberbullying_type = data[data['sentiment']=='other_cyberbullying']
age_type = data[data['sentiment']=='age']
ethnicity_type = data[data['sentiment']=='ethnicity']

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Gender Based Cyberbullying

# %%
gender = Counter([item for sublist in gender_type['tweet_list'] for item in sublist])
top20_gender = pd.DataFrame(gender.most_common(20))
top20_gender.columns = ['Top Words','Count']
top20_gender.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_340bd_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_340bd_row1_col1 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_340bd_row2_col1 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_340bd_row3_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_340bd_row4_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_340bd_row5_col1 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_340bd_row6_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_340bd_row7_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_340bd_row8_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_340bd_row9_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_340bd_row10_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_340bd_row11_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_340bd_row12_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_340bd_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_340bd_row14_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_340bd_row15_col1, #T_340bd_row16_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_340bd_row17_col1, #T_340bd_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_340bd_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_340bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_340bd_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_340bd_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_340bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_340bd_row0_col0" class="data row0 col0" >joke</td>
#       <td id="T_340bd_row0_col1" class="data row0 col1" >5173</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_340bd_row1_col0" class="data row1 col0" >rape</td>
#       <td id="T_340bd_row1_col1" class="data row1 col1" >4065</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_340bd_row2_col0" class="data row2 col0" >gay</td>
#       <td id="T_340bd_row2_col1" class="data row2 col1" >3850</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_340bd_row3_col0" class="data row3 col0" >call</td>
#       <td id="T_340bd_row3_col1" class="data row3 col1" >1400</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_340bd_row4_col0" class="data row4 col0" >make</td>
#       <td id="T_340bd_row4_col1" class="data row4 col1" >1280</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_340bd_row5_col0" class="data row5 col0" >woman</td>
#       <td id="T_340bd_row5_col1" class="data row5 col1" >1181</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_340bd_row6_col0" class="data row6 col0" >bitch</td>
#       <td id="T_340bd_row6_col1" class="data row6 col1" >1145</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_340bd_row7_col0" class="data row7 col0" >femal</td>
#       <td id="T_340bd_row7_col1" class="data row7 col1" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_340bd_row8_col0" class="data row8 col0" >peopl</td>
#       <td id="T_340bd_row8_col1" class="data row8 col1" >986</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_340bd_row9_col0" class="data row9 col0" >sexist</td>
#       <td id="T_340bd_row9_col1" class="data row9 col1" >952</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_340bd_row10_col0" class="data row10 col0" >funni</td>
#       <td id="T_340bd_row10_col1" class="data row10 col1" >660</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_340bd_row11_col0" class="data row11 col0" >men</td>
#       <td id="T_340bd_row11_col1" class="data row11 col1" >613</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_340bd_row12_col0" class="data row12 col0" >think</td>
#       <td id="T_340bd_row12_col1" class="data row12 col1" >589</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_340bd_row13_col0" class="data row13 col0" >fuck</td>
#       <td id="T_340bd_row13_col1" class="data row13 col1" >547</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_340bd_row14_col0" class="data row14 col0" >use</td>
#       <td id="T_340bd_row14_col1" class="data row14 col1" >440</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_340bd_row15_col0" class="data row15 col0" >amp</td>
#       <td id="T_340bd_row15_col1" class="data row15 col1" >434</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_340bd_row16_col0" class="data row16 col0" >girl</td>
#       <td id="T_340bd_row16_col1" class="data row16 col1" >422</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_340bd_row17_col0" class="data row17 col0" >man</td>
#       <td id="T_340bd_row17_col1" class="data row17 col1" >385</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_340bd_row18_col0" class="data row18 col0" >made</td>
#       <td id="T_340bd_row18_col1" class="data row18 col1" >370</td>
#     </tr>
#     <tr>
#       <th id="T_340bd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_340bd_row19_col0" class="data row19 col0" >know</td>
#       <td id="T_340bd_row19_col1" class="data row19 col1" >343</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_gender, y="Count", x="Top Words")
plt.title("Top 20 words in Gender Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Gender Cyberbullying')

# %%
plot_wordcloud('gender')

# %% [markdown]
# # Religion Based Cyberbullying

# %%
religion = Counter([item for sublist in religion_type['tweet_list'] for item in sublist])
top20_religion = pd.DataFrame(religion.most_common(20))
top20_religion.columns = ['Top Words','Count']
top20_religion.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_94904_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_94904_row1_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_94904_row2_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_94904_row3_col1 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_94904_row4_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_94904_row5_col1 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_94904_row6_col1 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_94904_row7_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_94904_row8_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_94904_row9_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_94904_row10_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_94904_row11_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_94904_row12_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_94904_row13_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_94904_row14_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_94904_row15_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_94904_row16_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_94904_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_94904_row18_col1, #T_94904_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_94904">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94904_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_94904_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94904_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94904_row0_col0" class="data row0 col0" >muslim</td>
#       <td id="T_94904_row0_col1" class="data row0 col1" >4617</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94904_row1_col0" class="data row1 col0" >idiot</td>
#       <td id="T_94904_row1_col1" class="data row1 col1" >3074</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94904_row2_col0" class="data row2 col0" >islam</td>
#       <td id="T_94904_row2_col1" class="data row2 col1" >2438</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94904_row3_col0" class="data row3 col0" >christian</td>
#       <td id="T_94904_row3_col1" class="data row3 col1" >2131</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94904_row4_col0" class="data row4 col0" >terrorist</td>
#       <td id="T_94904_row4_col1" class="data row4 col1" >1378</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94904_row5_col0" class="data row5 col0" >right</td>
#       <td id="T_94904_row5_col1" class="data row5 col1" >1288</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94904_row6_col0" class="data row6 col0" >support</td>
#       <td id="T_94904_row6_col1" class="data row6 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94904_row7_col0" class="data row7 col0" >woman</td>
#       <td id="T_94904_row7_col1" class="data row7 col1" >1246</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94904_row8_col0" class="data row8 col0" >terror</td>
#       <td id="T_94904_row8_col1" class="data row8 col1" >1181</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94904_row9_col0" class="data row9 col0" >radic</td>
#       <td id="T_94904_row9_col1" class="data row9 col1" >1109</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_94904_row10_col0" class="data row10 col0" >peopl</td>
#       <td id="T_94904_row10_col1" class="data row10 col1" >1076</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_94904_row11_col0" class="data row11 col0" >amp</td>
#       <td id="T_94904_row11_col1" class="data row11 col1" >769</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_94904_row12_col0" class="data row12 col0" >know</td>
#       <td id="T_94904_row12_col1" class="data row12 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_94904_row13_col0" class="data row13 col0" >human</td>
#       <td id="T_94904_row13_col1" class="data row13 col1" >743</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_94904_row14_col0" class="data row14 col0" >kill</td>
#       <td id="T_94904_row14_col1" class="data row14 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_94904_row15_col0" class="data row15 col0" >hindu</td>
#       <td id="T_94904_row15_col1" class="data row15 col1" >688</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_94904_row16_col0" class="data row16 col0" >isi</td>
#       <td id="T_94904_row16_col1" class="data row16 col1" >664</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_94904_row17_col0" class="data row17 col0" >quran</td>
#       <td id="T_94904_row17_col1" class="data row17 col1" >651</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_94904_row18_col0" class="data row18 col0" >religion</td>
#       <td id="T_94904_row18_col1" class="data row18 col1" >610</td>
#     </tr>
#     <tr>
#       <th id="T_94904_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_94904_row19_col0" class="data row19 col0" >countri</td>
#       <td id="T_94904_row19_col1" class="data row19 col1" >609</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_religion, y="Count", x="Top Words")
plt.title("Top 20 words in Religion Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Religion Cyberbullying')

# %%
plot_wordcloud('religion')

# %% [markdown]
# # Age based Cyberbullying

# %%
age = Counter([item for sublist in age_type['tweet_list'] for item in sublist])
top20_age = pd.DataFrame(age.most_common(20))
top20_age.columns = ['Top Words','Count']
top20_age.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_afb07_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_afb07_row1_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_afb07_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_afb07_row3_col1 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_afb07_row4_col1, #T_afb07_row5_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_afb07_row6_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_afb07_row7_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_afb07_row8_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_afb07_row9_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_afb07_row10_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_afb07_row11_col1, #T_afb07_row12_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_afb07_row13_col1, #T_afb07_row14_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_afb07_row15_col1, #T_afb07_row16_col1, #T_afb07_row17_col1, #T_afb07_row18_col1, #T_afb07_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_afb07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afb07_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_afb07_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afb07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afb07_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_afb07_row0_col1" class="data row0 col1" >8881</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afb07_row1_col0" class="data row1 col0" >school</td>
#       <td id="T_afb07_row1_col1" class="data row1 col1" >8411</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afb07_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_afb07_row2_col1" class="data row2 col1" >4849</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afb07_row3_col0" class="data row3 col0" >girl</td>
#       <td id="T_afb07_row3_col1" class="data row3 col1" >4610</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_afb07_row4_col0" class="data row4 col0" >peopl</td>
#       <td id="T_afb07_row4_col1" class="data row4 col1" >934</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_afb07_row5_col0" class="data row5 col0" >now</td>
#       <td id="T_afb07_row5_col1" class="data row5 col1" >908</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_afb07_row6_col0" class="data row6 col0" >got</td>
#       <td id="T_afb07_row6_col1" class="data row6 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_afb07_row7_col0" class="data row7 col0" >kid</td>
#       <td id="T_afb07_row7_col1" class="data row7 col1" >809</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_afb07_row8_col0" class="data row8 col0" >middl</td>
#       <td id="T_afb07_row8_col1" class="data row8 col1" >713</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_afb07_row9_col0" class="data row9 col0" >friend</td>
#       <td id="T_afb07_row9_col1" class="data row9 col1" >632</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_afb07_row10_col0" class="data row10 col0" >year</td>
#       <td id="T_afb07_row10_col1" class="data row10 col1" >586</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_afb07_row11_col0" class="data row11 col0" >go</td>
#       <td id="T_afb07_row11_col1" class="data row11 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_afb07_row12_col0" class="data row12 col0" >look</td>
#       <td id="T_afb07_row12_col1" class="data row12 col1" >543</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_afb07_row13_col0" class="data row13 col0" >amp</td>
#       <td id="T_afb07_row13_col1" class="data row13 col1" >527</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_afb07_row14_col0" class="data row14 col0" >know</td>
#       <td id="T_afb07_row14_col1" class="data row14 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_afb07_row15_col0" class="data row15 col0" >think</td>
#       <td id="T_afb07_row15_col1" class="data row15 col1" >467</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_afb07_row16_col0" class="data row16 col0" >time</td>
#       <td id="T_afb07_row16_col1" class="data row16 col1" >462</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_afb07_row17_col0" class="data row17 col0" >back</td>
#       <td id="T_afb07_row17_col1" class="data row17 col1" >456</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_afb07_row18_col0" class="data row18 col0" >make</td>
#       <td id="T_afb07_row18_col1" class="data row18 col1" >445</td>
#     </tr>
#     <tr>
#       <th id="T_afb07_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_afb07_row19_col0" class="data row19 col0" >use</td>
#       <td id="T_afb07_row19_col1" class="data row19 col1" >442</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_age, y="Count", x="Top Words")
plt.title("Top 20 words in Age Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Age Cyberbullying')

# %%
plot_wordcloud('age')

# %% [markdown]
# # Ethnicity based Cyberbullying

# %%
ethnicity = Counter([item for sublist in ethnicity_type['tweet_list'] for item in sublist])
top20_ethnicity = pd.DataFrame(ethnicity.most_common(20))
top20_ethnicity.columns = ['Top Words','Count']
top20_ethnicity.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_0554a_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0554a_row1_col1 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_0554a_row2_col1 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_0554a_row3_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_0554a_row4_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_0554a_row5_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_0554a_row6_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_0554a_row7_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_0554a_row8_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_0554a_row9_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_0554a_row10_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_0554a_row11_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_0554a_row12_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_0554a_row13_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_0554a_row14_col1, #T_0554a_row15_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_0554a_row16_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_0554a_row17_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_0554a_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_0554a_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_0554a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0554a_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_0554a_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0554a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0554a_row0_col0" class="data row0 col0" >fuck</td>
#       <td id="T_0554a_row0_col1" class="data row0 col1" >5850</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0554a_row1_col0" class="data row1 col0" >nigger</td>
#       <td id="T_0554a_row1_col1" class="data row1 col1" >5415</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0554a_row2_col0" class="data row2 col0" >dumb</td>
#       <td id="T_0554a_row2_col1" class="data row2 col1" >4962</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0554a_row3_col0" class="data row3 col0" >as</td>
#       <td id="T_0554a_row3_col1" class="data row3 col1" >2221</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0554a_row4_col0" class="data row4 col0" >black</td>
#       <td id="T_0554a_row4_col1" class="data row4 col1" >2132</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0554a_row5_col0" class="data row5 col0" >white</td>
#       <td id="T_0554a_row5_col1" class="data row5 col1" >1554</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0554a_row6_col0" class="data row6 col0" >call</td>
#       <td id="T_0554a_row6_col1" class="data row6 col1" >1380</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0554a_row7_col0" class="data row7 col0" >peopl</td>
#       <td id="T_0554a_row7_col1" class="data row7 col1" >1181</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0554a_row8_col0" class="data row8 col0" >obama</td>
#       <td id="T_0554a_row8_col1" class="data row8 col1" >1092</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0554a_row9_col0" class="data row9 col0" >bitch</td>
#       <td id="T_0554a_row9_col1" class="data row9 col1" >995</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0554a_row10_col0" class="data row10 col0" >first</td>
#       <td id="T_0554a_row10_col1" class="data row10 col1" >744</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0554a_row11_col0" class="data row11 col0" >anyth</td>
#       <td id="T_0554a_row11_col1" class="data row11 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0554a_row12_col0" class="data row12 col0" >racism</td>
#       <td id="T_0554a_row12_col1" class="data row12 col1" >687</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0554a_row13_col0" class="data row13 col0" >past</td>
#       <td id="T_0554a_row13_col1" class="data row13 col1" >670</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0554a_row14_col0" class="data row14 col0" >shit</td>
#       <td id="T_0554a_row14_col1" class="data row14 col1" >640</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0554a_row15_col0" class="data row15 col0" >negro</td>
#       <td id="T_0554a_row15_col1" class="data row15 col1" >640</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0554a_row16_col0" class="data row16 col0" >color</td>
#       <td id="T_0554a_row16_col1" class="data row16 col1" >581</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0554a_row17_col0" class="data row17 col0" >go</td>
#       <td id="T_0554a_row17_col1" class="data row17 col1" >552</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0554a_row18_col0" class="data row18 col0" >racist</td>
#       <td id="T_0554a_row18_col1" class="data row18 col1" >541</td>
#     </tr>
#     <tr>
#       <th id="T_0554a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0554a_row19_col0" class="data row19 col0" >disgust</td>
#       <td id="T_0554a_row19_col1" class="data row19 col1" >482</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_ethnicity, y="Count", x="Top Words")
plt.title("Top 20 words in Ethnicity Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Ethnicity Cyberbullying')

# %%
plot_wordcloud('ethnicity')

# %% [markdown]
# # Other types of Cyberbullying

# %%
other_cyberbullying = Counter([item for sublist in other_cyberbullying_type['tweet_list'] for item in sublist])
top20_other_cyberbullying = pd.DataFrame(other_cyberbullying.most_common(20))
top20_other_cyberbullying.columns = ['Top Words','Count']
top20_other_cyberbullying.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_2b560_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2b560_row1_col1 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_2b560_row2_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_2b560_row3_col1 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_2b560_row4_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_2b560_row5_col1, #T_2b560_row6_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_2b560_row7_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_2b560_row8_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_2b560_row9_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_2b560_row10_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_2b560_row11_col1, #T_2b560_row12_col1, #T_2b560_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_2b560_row14_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_2b560_row15_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_2b560_row16_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_2b560_row17_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_2b560_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_2b560_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_2b560">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b560_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_2b560_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b560_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b560_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_2b560_row0_col1" class="data row0 col1" >878</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b560_row1_col0" class="data row1 col0" >fuck</td>
#       <td id="T_2b560_row1_col1" class="data row1 col1" >506</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b560_row2_col0" class="data row2 col0" >peopl</td>
#       <td id="T_2b560_row2_col1" class="data row2 col1" >352</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b560_row3_col0" class="data row3 col0" >go</td>
#       <td id="T_2b560_row3_col1" class="data row3 col1" >276</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b560_row4_col0" class="data row4 col0" >idiot</td>
#       <td id="T_2b560_row4_col1" class="data row4 col1" >256</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b560_row5_col0" class="data row5 col0" >know</td>
#       <td id="T_2b560_row5_col1" class="data row5 col1" >237</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b560_row6_col0" class="data row6 col0" >think</td>
#       <td id="T_2b560_row6_col1" class="data row6 col1" >236</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b560_row7_col0" class="data row7 col0" >make</td>
#       <td id="T_2b560_row7_col1" class="data row7 col1" >213</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b560_row8_col0" class="data row8 col0" >time</td>
#       <td id="T_2b560_row8_col1" class="data row8 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b560_row9_col0" class="data row9 col0" >hate</td>
#       <td id="T_2b560_row9_col1" class="data row9 col1" >197</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2b560_row10_col0" class="data row10 col0" >now</td>
#       <td id="T_2b560_row10_col1" class="data row10 col1" >189</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2b560_row11_col0" class="data row11 col0" >want</td>
#       <td id="T_2b560_row11_col1" class="data row11 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2b560_row12_col0" class="data row12 col0" >thing</td>
#       <td id="T_2b560_row12_col1" class="data row12 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2b560_row13_col0" class="data row13 col0" >need</td>
#       <td id="T_2b560_row13_col1" class="data row13 col1" >181</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2b560_row14_col0" class="data row14 col0" >see</td>
#       <td id="T_2b560_row14_col1" class="data row14 col1" >178</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2b560_row15_col0" class="data row15 col0" >got</td>
#       <td id="T_2b560_row15_col1" class="data row15 col1" >175</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2b560_row16_col0" class="data row16 col0" >use</td>
#       <td id="T_2b560_row16_col1" class="data row16 col1" >169</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2b560_row17_col0" class="data row17 col0" >call</td>
#       <td id="T_2b560_row17_col1" class="data row17 col1" >165</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2b560_row18_col0" class="data row18 col0" >as</td>
#       <td id="T_2b560_row18_col1" class="data row18 col1" >155</td>
#     </tr>
#     <tr>
#       <th id="T_2b560_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2b560_row19_col0" class="data row19 col0" >look</td>
#       <td id="T_2b560_row19_col1" class="data row19 col1" >152</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_other_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Other Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Other Cyberbullying')

# %%
plot_wordcloud('other_cyberbullying')

# %% [markdown]
# # Tweets without Cyberbullying

# %%
not_cyberbullying = Counter([item for sublist in not_cyberbullying_type['tweet_list'] for item in sublist])
top20_not_cyberbullying = pd.DataFrame(not_cyberbullying.most_common(20))
top20_not_cyberbullying.columns = ['Top Words','Count']
top20_not_cyberbullying.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_ebdd3_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ebdd3_row1_col1 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_ebdd3_row2_col1 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_ebdd3_row3_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_ebdd3_row4_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_ebdd3_row5_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_ebdd3_row6_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_ebdd3_row7_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_ebdd3_row8_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_ebdd3_row9_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_ebdd3_row10_col1, #T_ebdd3_row11_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_ebdd3_row12_col1, #T_ebdd3_row13_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_ebdd3_row14_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_ebdd3_row15_col1, #T_ebdd3_row16_col1, #T_ebdd3_row17_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_ebdd3_row18_col1, #T_ebdd3_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_ebdd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebdd3_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_ebdd3_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebdd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebdd3_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_ebdd3_row0_col1" class="data row0 col1" >1103</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebdd3_row1_col0" class="data row1 col0" >go</td>
#       <td id="T_ebdd3_row1_col1" class="data row1 col1" >390</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ebdd3_row2_col0" class="data row2 col0" >school</td>
#       <td id="T_ebdd3_row2_col1" class="data row2 col1" >374</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ebdd3_row3_col0" class="data row3 col0" >kat</td>
#       <td id="T_ebdd3_row3_col1" class="data row3 col1" >283</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ebdd3_row4_col0" class="data row4 col0" >peopl</td>
#       <td id="T_ebdd3_row4_col1" class="data row4 col1" >271</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ebdd3_row5_col0" class="data row5 col0" >amp</td>
#       <td id="T_ebdd3_row5_col1" class="data row5 col1" >254</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ebdd3_row6_col0" class="data row6 col0" >think</td>
#       <td id="T_ebdd3_row6_col1" class="data row6 col1" >242</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ebdd3_row7_col0" class="data row7 col0" >know</td>
#       <td id="T_ebdd3_row7_col1" class="data row7 col1" >227</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ebdd3_row8_col0" class="data row8 col0" >time</td>
#       <td id="T_ebdd3_row8_col1" class="data row8 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ebdd3_row9_col0" class="data row9 col0" >make</td>
#       <td id="T_ebdd3_row9_col1" class="data row9 col1" >217</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ebdd3_row10_col0" class="data row10 col0" >now</td>
#       <td id="T_ebdd3_row10_col1" class="data row10 col1" >208</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ebdd3_row11_col0" class="data row11 col0" >love</td>
#       <td id="T_ebdd3_row11_col1" class="data row11 col1" >205</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ebdd3_row12_col0" class="data row12 col0" >andr</td>
#       <td id="T_ebdd3_row12_col1" class="data row12 col1" >193</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ebdd3_row13_col0" class="data row13 col0" >need</td>
#       <td id="T_ebdd3_row13_col1" class="data row13 col1" >191</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ebdd3_row14_col0" class="data row14 col0" >woman</td>
#       <td id="T_ebdd3_row14_col1" class="data row14 col1" >189</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ebdd3_row15_col0" class="data row15 col0" >see</td>
#       <td id="T_ebdd3_row15_col1" class="data row15 col1" >186</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ebdd3_row16_col0" class="data row16 col0" >fuck</td>
#       <td id="T_ebdd3_row16_col1" class="data row16 col1" >186</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ebdd3_row17_col0" class="data row17 col0" >want</td>
#       <td id="T_ebdd3_row17_col1" class="data row17 col1" >183</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ebdd3_row18_col0" class="data row18 col0" >look</td>
#       <td id="T_ebdd3_row18_col1" class="data row18 col1" >175</td>
#     </tr>
#     <tr>
#       <th id="T_ebdd3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ebdd3_row19_col0" class="data row19 col0" >good</td>
#       <td id="T_ebdd3_row19_col1" class="data row19 col1" >172</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_not_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Not Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Not Cyberbullying')

# %%
plot_wordcloud('not_cyberbullying')

# %%
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying  \
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text
# 0                  6                     word katandandr food crapilici  \
# 1                  6  aussietv white theblock imacelebrityau today s...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6      isi account pretend kurdish account islam lie
#
#                                           tweet_list  text_len
# 0                [word, katandandr, food, crapilici]         4
# 1  [aussietv, white, theblock, imacelebrityau, to...        10
# 2               [classi, whore, red, velvet, cupcak]         5
# 3  [meh, p, thank, head, concern, anoth, angri, d...         9
# 4  [isi, account, pretend, kurdish, account, isla...         7

# %%
sentiments = ["religion", "age", "ethnicity", "gender", "other_cyberbullying","not_cyberbullying"]

# %% [markdown]
# # Splitting Data into Train and Test Sets

# %%
X,Y = data['cleaned_text'],data['sentiment_encoded']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, stratify =Y, random_state = 42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (31061,) (31061,) (13312,) (13312,)

# %% [markdown]
# ## tf-idf Vectorization

# %%
tf_idf = TfidfVectorizer()
X_train_tf = tf_idf.fit_transform(X_train)
X_test_tf = tf_idf.transform(X_test)
print(X_train_tf.shape)
print(X_test_tf.shape)
# Out:
# (31061, 29359)
# (13312, 29359)

# %% [markdown]
# # Trying Different ML Models

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = LogisticRegression()

# %%
log_cv_score = cross_val_score(log_reg,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=1)

# %%
mean_log_cv = np.mean(log_cv_score)
mean_log_cv
# Out:
# 0.8160450643691449

# %% [markdown]
# ## Support Vector Classifier

# %%
lin_svc = LinearSVC(C=1, loss='hinge')

# %%
lin_svc_cv_score = cross_val_score(lin_svc,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=1)
mean_lin_svc_cv = np.mean(lin_svc_cv_score)
mean_lin_svc_cv
# Out:
# 0.8208098555781376

# %% [markdown]
# ## Naive Bayes Classifier

# %%
multiNB = MultinomialNB()

# %%
multiNB_cv_score = cross_val_score(multiNB,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_multiNB_cv = np.mean(multiNB_cv_score)
mean_multiNB_cv
# Out:
# 0.6609495553538833

# %% [markdown]
# ## Decison Tree Classifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree_cv_score = cross_val_score(dtree,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_dtree_cv = np.mean(dtree_cv_score)
mean_dtree_cv
# Out:
# 0.7989922869549829

# %% [markdown]
# ## RandomForest Classifier

# %%
rand_forest = RandomForestClassifier()

# %%
rand_forest_cv_score = cross_val_score(rand_forest,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_rand_forest_cv = np.mean(rand_forest_cv_score)
mean_rand_forest_cv
# Out:
# 0.8238046116196192

# %% [markdown]
# ## Adaboost Classifier

# %%
adab = AdaBoostClassifier()

# %%
adab_cv_score = cross_val_score(adab,X_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_adab_cv = np.mean(adab_cv_score)
mean_adab_cv
# Out:
# 0.7462732624796359

# %% [markdown]
# ## By trying different models we can see logistic regression, svm and random forest classifier performed similarly, so among these we will go with svm model as it is more generalised and light

# %% [markdown]
# ## Fine Tuning Support Vector Classifier

# %%
svc1 = LinearSVC()
param_grid = {'C':[0.0001,0.001,0.01,0.1,1,10],
             'loss':['hinge','squared_hinge'],
             'fit_intercept':[True,False]}
grid_search = GridSearchCV(svc1,param_grid,cv=5,scoring='f1_macro',n_jobs=1,verbose=0,return_train_score=True)
grid_search.fit(X_train_tf,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearSVC(), n_jobs=1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#                          'fit_intercept': [True, False],
#                          'loss': ['hinge', 'squared_hinge']},
#              return_train_score=True, scoring='f1_macro')

# %%
grid_search.best_estimator_
# Out:
# LinearSVC(C=1, loss='hinge')

# %%
grid_search.best_score_
# Out:
# 0.8208098555781376

# %% [markdown]
# # Model Evaluation

# %%
multiNB.fit(X_train_tf,y_train)
y_pred = multiNB.predict(X_test_tf)

# %%
log_reg.fit(X_train_tf,y_train)
y_pred = log_reg.predict(X_test_tf)

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names)
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Prediction')

# %%
cm = confusion_matrix(y_test,y_pred)
print_confusion_matrix(cm,sentiments)

# %%
print('Classification Report:\n',classification_report(y_test, y_pred, target_names=sentiments))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#            religion       0.94      0.94      0.94      2384
#                 age       0.93      0.97      0.95      2360
#           ethnicity       0.97      0.97      0.97      2318
#              gender       0.91      0.83      0.87      2263
# other_cyberbullying       0.59      0.54      0.56      1714
#   not_cyberbullying       0.59      0.66      0.63      2273
#
#            accuracy                           0.83     13312
#           macro avg       0.82      0.82      0.82     13312
#        weighted avg       0.83      0.83      0.83     13312

# %% [markdown]
# # Linier

# %%
lin_svc.fit(X_train_tf,y_train)
yLin_pred = lin_svc.predict(X_test_tf)

# %%
cm = confusion_matrix(y_test,yLin_pred)
print_confusion_matrix(cm,sentiments)

# %%
print('Classification Report:\n',classification_report(y_test, yLin_pred, target_names=sentiments))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#            religion       0.94      0.96      0.95      2384
#                 age       0.92      0.98      0.95      2360
#           ethnicity       0.96      0.98      0.97      2318
#              gender       0.89      0.85      0.87      2263
# other_cyberbullying       0.59      0.55      0.57      1714
#   not_cyberbullying       0.61      0.60      0.61      2273
#
#            accuracy                           0.83     13312
#           macro avg       0.82      0.82      0.82     13312
#        weighted avg       0.83      0.83      0.83     13312

# %% [markdown]
# # Saving Model

# %%
pickle.dump(tf_idf, open('vectorizer.pkl', 'wb'))
pickle.dump(lin_svc, open('model_svc.pkl', 'wb'))
pickle.dump(log_reg, open('model_logreg.pkl', 'wb'))
pickle.dump(multiNB, open('model_NB.pkl', 'wb'))

# %%
# !ls
# Out:
# FullBAB_Eska_Smara_Update CM_asli - Copy.docx
# Revisi Dokumen TA_Khansa Ardya_M0515022.docx
# app_.py
# app_cyberNBC.py
# bullying.py
# cyberbullying-tweet.ipynb
# cyberbullying_tweets.csv
# cyberbullying_tweets.csv.zip
# model.pkl
# model_NB.pkl
# model_logreg.pkl
# model_svc.pkl
# readme.md
# twit.png
# twitter.png
# twitter_mask.png
# vectorizer.pkl
